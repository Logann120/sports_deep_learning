# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_style('darkgrid')
import sklearn as skl
from sklearn import metrics
import PIL

# %%
df = pd.read_csv('normData.csv', index_col='Unnamed: 0')

# %%
pd.options.display.max_columns = None
pd.options.display.max_rows = None

# %%
df.head()
# Out:
#    Home_win_stat  Recent_wins  Pass_comp_percentage  Rush_attempt  \
# 0       0.047619     0.666667              0.697985      0.301587
# 1       0.047619     0.000000              0.633046      0.198413
# 2       0.047619     0.333333              0.641071      0.198413
# 3       0.047619     1.000000              0.713304      0.269841
# 4       0.047619     0.333333              0.416452      0.309524
#
#    Yards_gained  Third_down_converted  Fourth_down_converted  \
# 0      0.317489              0.419355               0.181818
# 1      0.138940              0.225806               0.000000
# 2      0.349787              0.322581               0.272727
# 3      0.487508              0.387097               0.090909
# 4      0.348568              0.483871               0.272727
#
#    Punt_inside_twenty  Interception    Qb_hit      Sack  Punt_blocked  \
# 0            0.333333           0.5  0.526316  0.500000           0.0
# 1            0.466667           0.6  0.289474  0.277778           0.0
# 2            0.200000           0.2  0.368421  0.055556           0.0
# 3            0.133333           0.2  0.500000  0.388889           0.0
# 4            0.266667           0.1  0.289474  0.166667           0.0
#
#    Own_kickoff_recovery  Penalty_yards  Recent_wins_away  \
# 0                   0.0       0.298122          0.333333
# 1                   0.0       0.274648          0.666667
# 2                   0.0       0.232394          0.333333
# 3                   0.0       0.159624          0.333333
# 4                   0.0       0.178404          0.000000
#
#    Pass_comp_percentage_away  Rush_attempt_away  Yards_gained_away  \
# 0                   0.502130           0.404959           0.337731
# 1                   0.656040           0.322314           0.353562
# 2                   0.301550           0.322314           0.200528
# 3                   0.677414           0.363636           0.468338
# 4                   0.525074           0.330579           0.455145
#
#    Third_down_converted_away  Fourth_down_converted_away  \
# 0                   0.517241                        0.50
# 1                   0.482759                        0.50
# 2                   0.344828                        0.25
# 3                   0.551724                        0.25
# 4                   0.344828                        0.00
#
#    Punt_inside_twenty_away  Interception_away  Qb_hit_away  Sack_away  \
# 0                 0.428571           0.454545     0.242424       0.25
# 1                 0.571429           0.363636     0.454545       0.50
# 2                 0.285714           0.363636     0.242424       0.25
# 3                 0.214286           0.363636     0.424242       0.45
# 4                 0.214286           0.363636     0.393939       0.35
#
#    Punt_blocked_away  Own_kickoff_recovery_away  Penalty_yards_away  Home_win
# 0                0.0                        0.0            0.441088       1.0
# 1                0.0                        0.5            0.362538       0.0
# 2                0.0                        0.0            0.305136       1.0
# 3                0.0                        0.0            0.235650       1.0
# 4                0.0                        0.0            0.211480       1.0

# %%
cor_mat = df.corr()
sns.heatmap(cor_mat, linewidths=1, square=True)
# Out:
# <AxesSubplot:>

# %%
sns.scatterplot(x=df.Home_win_stat, y=df.yards_gained, hue=df.Home_win_stat)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20188/17615633.py in <module>
# ----> 1 sns.scatterplot(x=df.home_win_stat, y=df.yards_gained, hue=df.Home_win)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'home_win_stat'

# %%
sample = df.sample(n=350)

# %%
sns.kdeplot(x=df.Recent_wins, y=df.Recent_wins_away, hue=df.Home_win, fill=True, alpha=0.65,
    gridsize=750, hue_order=[1,0], palette=[(4/255,2/255,225/255), (255/255,125/255,5/255)], thresh=0.3)
# Out:
# <AxesSubplot:xlabel='Recent_wins', ylabel='Recent_wins_away'>
