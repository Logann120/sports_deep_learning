# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_style('darkgrid')

# %%
df = pd.read_csv('normData.csv', index_col='Unnamed: 0')

# %%
pd.options.display.max_columns = None
pd.options.display.max_rows = None

# %%
df.head()
# Out:
#    Recent_wins  Home_win_stat     Drive  Yards_gained  Punt_blocked  \
# 0     0.333333      -0.904762  0.478261     -0.083696          -1.0
# 1    -1.000000      -0.904762  0.478261     -0.367199          -1.0
# 2    -0.333333      -0.904762  0.391304     -0.032414          -1.0
# 3     1.000000      -0.904762  0.260870      0.186260          -1.0
# 4    -0.333333      -0.904762  0.304348     -0.034349          -1.0
#
#    First_down_rush  First_down_pass  Third_down_converted  Third_down_failed  \
# 0        -0.653846        -0.088608             -0.090909           0.181818
# 1        -0.692308        -0.316456             -0.454545           0.318182
# 2        -0.576923        -0.012658             -0.272727           0.090909
# 3        -0.500000         0.037975             -0.151515          -0.181818
# 4        -0.153846        -0.316456              0.030303           0.136364
#
#    Fourth_down_converted  Fourth_down_failed  Interception  \
# 0              -0.636364           -0.428571           0.0
# 1              -1.000000           -0.714286           0.2
# 2              -0.454545           -0.714286          -0.6
# 3              -0.818182           -0.142857          -0.6
# 4              -0.454545           -0.428571          -0.8
#
#    Punt_inside_twenty  Punt_in_endzone  Kickoff_inside_twenty  \
# 0           -0.333333             -1.0              -1.000000
# 1           -0.066667             -1.0              -0.333333
# 2           -0.600000             -1.0              -0.555556
# 3           -0.733333             -1.0              -1.000000
# 4           -0.466667             -1.0              -0.333333
#
#    Kickoff_in_endzone  Solo_tackle  Tackled_for_loss  Own_kickoff_recovery  \
# 0           -0.285714     0.292929         -0.043478                  -1.0
# 1            0.142857     0.363636         -0.304348                  -1.0
# 2            0.428571     0.070707         -0.130435                  -1.0
# 3           -0.571429     0.080808         -0.478261                  -1.0
# 4           -0.428571     0.030303         -0.391304                  -1.0
#
#    Rush_attempt  Sack  Punt_attempt    Fumble  Pass_comp_percentage  \
# 0     -0.066667 -0.60      0.000000 -0.384615              0.652428
# 1     -0.224242 -0.12      0.142857 -0.230769              0.577694
# 2     -0.224242 -0.68      0.142857 -0.076923              0.586929
# 3     -0.115152 -0.84     -0.357143 -0.692308              0.670058
# 4     -0.054545 -0.60     -0.142857  0.076923              0.328428
#
#    Away_drive  Yards_gained_away  Punt_blocked_away  Away_first_down_rush  \
# 0    0.347826          -0.067517               -1.0             -0.254902
# 1    0.347826          -0.041999               -1.0             -0.372549
# 2    0.347826          -0.288676               -1.0             -0.411765
# 3    0.565217           0.143009               -1.0             -0.372549
# 4    0.739130           0.121744               -1.0             -0.333333
#
#    Away_first_down_pass  Third_down_converted_away  Away_third_down_failed  \
# 0             -0.308642                     0.1250                0.285714
# 1             -0.160494                     0.0625                0.142857
# 2             -0.530864                    -0.1875                0.142857
# 3              0.012346                     0.1875                0.285714
# 4             -0.185185                    -0.1875                0.190476
#
#    Fourth_down_converted_away  Away_fourth_down_failed  Interception_away  \
# 0                         0.0                    -1.00          -0.090909
# 1                         0.0                    -0.75          -0.272727
# 2                        -0.5                    -0.75          -0.272727
# 3                        -0.5                    -0.50          -0.272727
# 4                        -1.0                    -0.25          -0.272727
#
#    Punt_inside_twenty_away  Punt_in_endzone_away  Away_kickoff_inside_twenty  \
# 0                -0.142857                  -1.0                         0.0
# 1                 0.142857                  -1.0                        -0.6
# 2                -0.428571                  -1.0                        -0.6
# 3                -0.571429                  -1.0                        -0.8
# 4                -0.571429                  -1.0                        -0.6
#
#    Away_kickoff_in_endzone  Away_solo_tackle  Away_tackled_for_loss  \
# 0                -0.384615          0.494845               0.043478
# 1                -0.538462          0.144330              -0.391304
# 2                -0.538462          0.185567              -0.652174
# 3                -0.538462          0.546392              -0.391304
# 4                -0.076923          0.175258               0.217391
#
#    Own_kickoff_recovery_away  Rush_attempt_away  Sack_away  Away_punt_attempt  \
# 0                       -1.0           0.111111  -0.545455           0.153846
# 1                        0.0          -0.012346  -0.363636           0.230769
# 2                       -1.0          -0.012346  -0.454545           0.153846
# 3                       -1.0           0.049383  -0.636364           0.076923
# 4                       -1.0           0.000000  -0.636364           0.307692
#
#    Away_fumble  Pass_comp_percentage_away  Recent_wins_away  Home_win
# 0    -0.166667                   0.380354         -0.333333       1.0
# 1    -0.500000                   0.571910          0.333333       0.0
# 2     0.000000                   0.130714         -0.333333       1.0
# 3    -0.166667                   0.598512         -0.333333       1.0
# 4    -0.333333                   0.408910         -1.000000       1.0

# %%
cor_mat = df.corr()
sns.heatmap(cor_mat, linewidths=1, square=True)
# Out:
# <Axes: >

# %%
sns.scatterplot(x=df.Home_win_stat, y=df.Yards_gained, hue=df.Home_win_stat)
# Out:
# <Axes: xlabel='Home_win_stat', ylabel='Yards_gained'>

# %%
sample = df.sample(n=350)

# %%
sns.kdeplot(x=df.Recent_wins, y=df.Recent_wins_away, hue=df.Home_win, fill=True, alpha=0.65,
    gridsize=750, hue_order=[1,0], palette=[(4/255,2/255,225/255), (255/255,125/255,5/255)], thresh=0.3)
# Out:
# <Axes: xlabel='Recent_wins', ylabel='Recent_wins_away'>
